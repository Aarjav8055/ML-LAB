# %% [markdown]
# <a href="https://colab.research.google.com/github/Aarjav8055/ML-LAB/blob/main/LAB2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/parkinsons.data")

# %%
# Drop unnecessary column
df.drop("name", axis=1, inplace=True)

# Missing values
print(df.isnull().sum())

# Visualization
plt.hist(df["MDVP:Fo(Hz)"])
plt.title("Feature Distribution")
plt.show()
# Out:
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_15591/3345291327.py in <cell line: 0>()
#       6
#       7 # Visualization
# ----> 8 plt.hist(df["MDVP:Fo(Hz)"])
#       9 plt.title("Feature Distribution")
#      10 plt.show()
#
# NameError: name 'plt' is not defined
